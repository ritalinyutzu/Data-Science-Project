# %% [markdown]
# <a href="https://colab.research.google.com/github/CubatLin/Data-Science-Project/blob/main/Quantitative%20Finance%20Research%20-%20X_1~X_69/Quantitative_Finance_Research_KDE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Information:
# * Author : Ethan Wu
# * Job Role : Quantitative Finance Research(金融計量研究人員)
# * Contact : ethan1126.ilink@gmail.com
#
# ![截圖 2021-07-20 上午10.19.57.png](data:image/png;base64,...)

# %% [markdown]
# ### Load Data

# %%
def import_data_from_drive(id):
  # !wget --save-cookies cookies.txt 'https://docs.google.com/uc?export=download&id='{id} -O- \
  | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1/p' > confirm.txt && wget --content-disposition --load-cookies cookies.txt 'https://docs.google.com/uc?export=download&id='{id}'&confirm='$(<confirm.txt)

# %%
import_data_from_drive('1-1bEtnTqjRvYnhobN72aWI1E4KLAd2kz')
# Out:
# --2021-07-20 05:33:08--  https://docs.google.com/uc?export=download&id=1-1bEtnTqjRvYnhobN72aWI1E4KLAd2kz
# Resolving docs.google.com (docs.google.com)... 74.125.141.113, 74.125.141.139, 74.125.141.101, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘STDOUT’
#
# -                       [ <=>                ]   3.20K  --.-KB/s    in 0s
#
# 2021-07-20 05:33:08 (23.9 MB/s) - written to stdout [3277]
#
# --2021-07-20 05:33:08--  https://docs.google.com/uc?export=download&id=1-1bEtnTqjRvYnhobN72aWI1E4KLAd2kz&confirm=hsdS
# Resolving docs.google.com (docs.google.com)... 74.125.141.101, 74.125.141.113, 74.125.141.100, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-a4-docs.googleusercontent.com/docs/securesc/c1p87f773mokm976nu127i278pk225dv/7rsnq41n2mpg3rvg898u9fpa2v5eo8no/1626759150000/12626892632851982799/09473438621923830778Z/1-1bEtnTqjRvYnhobN72aWI1E4KLAd2kz?e=download [following]
# --2021-07-20 05:33:08--  https://doc-0c-a4-docs.googleusercontent.com/docs/securesc/c1p87f773mokm976nu127i278pk225dv/7rsnq41n2mpg3rvg898u9fpa2v5eo8no/1626759150000/12626892632851982799/09473438621923830778Z/1-1bEtnTqjRvYnhobN72aWI1E4KLAd2kz?e=download
# Resolving doc-0c-a4-docs.googleusercontent.com (doc-0c-a4-docs.googleusercontent.com)... 173.194.210.132, 2607:f8b0:400c:c0f::84
# Connecting to doc-0c-a4-docs.googleusercontent.com (doc-0c-a4-docs.googleusercontent.com)|173.194.210.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=fhc8atrs070p8&continue=https://doc-0c-a4-docs.googleusercontent.com/docs/securesc/c1p87f773mokm976nu127i278pk225dv/7rsnq41n2mpg3rvg898u9fpa2v5eo8no/1626759150000/12626892632851982799/09473438621923830778Z/1-1bEtnTqjRvYnhobN72aWI1E4KLAd2kz?e%3Ddownload&hash=bm75se9h5c9ado8h2at3vkjb9rcr24e2 [following]
# --2021-07-20 05:33:08--  https://docs.google.com/nonceSigner?nonce=fhc8atrs070p8&continue=https://doc-0c-a4-docs.googleusercontent.com/docs/securesc/c1p87f773mokm976nu127i278pk225dv/7rsnq41n2mpg3rvg898u9fpa2v5eo8no/1626759150000/12626892632851982799/09473438621923830778Z/1-1bEtnTqjRvYnhobN72aWI1E4KLAd2kz?e%3Ddownload&hash=bm75se9h5c9ado8h2at3vkjb9rcr24e2
# Connecting to docs.google.com (docs.google.com)|74.125.141.101|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# The name is too long, 325 chars total.
# Trying to shorten...
# New name is nonceSigner?nonce=fhc8atrs070p8&continue=https:%2F%2Fdoc-0c-a4-docs.googleusercontent.com%2Fdocs%2Fsecuresc%2Fc1p87f773mokm976nu127i278pk225dv%2F7rsnq41n2mpg3rvg898u9fpa2v5eo8no%2F1626759150000%2F12626892632851982799%2F09473438621923830.
# Location: https://doc-0c-a4-docs.googleusercontent.com/docs/securesc/c1p87f773mokm976nu127i278pk225dv/7rsnq41n2mpg3rvg898u9fpa2v5eo8no/1626759150000/12626892632851982799/09473438621923830778Z/1-1bEtnTqjRvYnhobN72aWI1E4KLAd2kz?e=download&nonce=fhc8atrs070p8&user=09473438621923830778Z&hash=v6s6hup3ih8shu4ig644ddfnradgi723 [following]
# --2021-07-20 05:33:08--  https://doc-0c-a4-docs.googleusercontent.com/docs/securesc/c1p87f773mokm976nu127i278pk225dv/7rsnq41n2mpg3rvg898u9fpa2v5eo8no/1626759150000/12626892632851982799/09473438621923830778Z/1-1bEtnTqjRvYnhobN72aWI1E4KLAd2kz?e=download&nonce=fhc8atrs070p8&user=09473438621923830778Z&hash=v6s6hup3ih8shu4ig644ddfnradgi723
# Connecting to doc-0c-a4-docs.googleusercontent.com (doc-0c-a4-docs.googleusercontent.com)|173.194.210.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘train_ethanwu.csv.3’
#
# train_ethanwu.csv.3     [     <=>            ]   1.44G   170MB/s    in 7.8s
#
# 2021-07-20 05:33:16 (189 MB/s) - ‘train_ethanwu.csv.3’ saved [1543486627]

# %%
import_data_from_drive('1-74clMol_8xh9nccA4l0kC36kHAFxdjT')
# Out:
# --2021-07-20 05:33:16--  https://docs.google.com/uc?export=download&id=1-74clMol_8xh9nccA4l0kC36kHAFxdjT
# Resolving docs.google.com (docs.google.com)... 74.125.141.139, 74.125.141.102, 74.125.141.100, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.139|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘STDOUT’
#
# -                       [ <=>                ]   3.20K  --.-KB/s    in 0s
#
# 2021-07-20 05:33:17 (89.2 MB/s) - written to stdout [3276]
#
# --2021-07-20 05:33:17--  https://docs.google.com/uc?export=download&id=1-74clMol_8xh9nccA4l0kC36kHAFxdjT&confirm=Nlpg
# Resolving docs.google.com (docs.google.com)... 74.125.141.138, 74.125.141.101, 74.125.141.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.141.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0o-3c-docs.googleusercontent.com/docs/securesc/36g7p68h0rr9gnqjk3ao6c3dmdikg5at/75qn2llr8mi52glfh0gb9s70fg29q6kd/1626759150000/12626892632851982799/00149491562358100918Z/1-74clMol_8xh9nccA4l0kC36kHAFxdjT?e=download [following]
# --2021-07-20 05:33:17--  https://doc-0o-3c-docs.googleusercontent.com/docs/securesc/36g7p68h0rr9gnqjk3ao6c3dmdikg5at/75qn2llr8mi52glfh0gb9s70fg29q6kd/1626759150000/12626892632851982799/00149491562358100918Z/1-74clMol_8xh9nccA4l0kC36kHAFxdjT?e=download
# Resolving doc-0o-3c-docs.googleusercontent.com (doc-0o-3c-docs.googleusercontent.com)... 173.194.210.132, 2607:f8b0:400c:c0f::84
# Connecting to doc-0o-3c-docs.googleusercontent.com (doc-0o-3c-docs.googleusercontent.com)|173.194.210.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=ev5m3ne0oiq3s&continue=https://doc-0o-3c-docs.googleusercontent.com/docs/securesc/36g7p68h0rr9gnqjk3ao6c3dmdikg5at/75qn2llr8mi52glfh0gb9s70fg29q6kd/1626759150000/12626892632851982799/00149491562358100918Z/1-74clMol_8xh9nccA4l0kC36kHAFxdjT?e%3Ddownload&hash=m4p3asmcqsi6encku1sf3oi07rhbf95c [following]
# --2021-07-20 05:33:17--  https://docs.google.com/nonceSigner?nonce=ev5m3ne0oiq3s&continue=https://doc-0o-3c-docs.googleusercontent.com/docs/securesc/36g7p68h0rr9gnqjk3ao6c3dmdikg5at/75qn2llr8mi52glfh0gb9s70fg29q6kd/1626759150000/12626892632851982799/00149491562358100918Z/1-74clMol_8xh9nccA4l0kC36kHAFxdjT?e%3Ddownload&hash=m4p3asmcqsi6encku1sf3oi07rhbf95c
# Connecting to docs.google.com (docs.google.com)|74.125.141.138|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# The name is too long, 325 chars total.
# Trying to shorten...
# New name is nonceSigner?nonce=ev5m3ne0oiq3s&continue=https:%2F%2Fdoc-0o-3c-docs.googleusercontent.com%2Fdocs%2Fsecuresc%2F36g7p68h0rr9gnqjk3ao6c3dmdikg5at%2F75qn2llr8mi52glfh0gb9s70fg29q6kd%2F1626759150000%2F12626892632851982799%2F00149491562358100.
# Location: https://doc-0o-3c-docs.googleusercontent.com/docs/securesc/36g7p68h0rr9gnqjk3ao6c3dmdikg5at/75qn2llr8mi52glfh0gb9s70fg29q6kd/1626759150000/12626892632851982799/00149491562358100918Z/1-74clMol_8xh9nccA4l0kC36kHAFxdjT?e=download&nonce=ev5m3ne0oiq3s&user=00149491562358100918Z&hash=knvq8oj5v03m4kkmgati9eueird79bsm [following]
# --2021-07-20 05:33:17--  https://doc-0o-3c-docs.googleusercontent.com/docs/securesc/36g7p68h0rr9gnqjk3ao6c3dmdikg5at/75qn2llr8mi52glfh0gb9s70fg29q6kd/1626759150000/12626892632851982799/00149491562358100918Z/1-74clMol_8xh9nccA4l0kC36kHAFxdjT?e=download&nonce=ev5m3ne0oiq3s&user=00149491562358100918Z&hash=knvq8oj5v03m4kkmgati9eueird79bsm
# Connecting to doc-0o-3c-docs.googleusercontent.com (doc-0o-3c-docs.googleusercontent.com)|173.194.210.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘eval_ethanwu.csv.3’
#
# eval_ethanwu.csv.3      [   <=>              ]   1.50G  28.9MB/s    in 41s
#
# 2021-07-20 05:33:58 (37.6 MB/s) - ‘eval_ethanwu.csv.3’ saved [1616208946]

# %%
import pandas as pd
train_new=pd.read_csv('/content/train_ethanwu.csv')
eval_new=pd.read_csv('/content/eval_ethanwu.csv')

# %%
train_new.head(3)
# Out:
#         X_0       X_1       X_2       X_3  ...    X_ec_6    X_ec_7  K_Group  K_Dis
# 0  0.853843 -0.709693  0.142649 -0.176952  ... -1.550606 -1.189766      NaN    NaN
# 1  1.128771 -0.029401  0.142649 -0.176952  ... -1.490602 -1.076384      NaN    NaN
# 2  0.508191 -0.029401  0.142649 -0.176952  ... -3.024776 -1.295628      NaN    NaN
#
# [3 rows x 83 columns]

# %% [markdown]
# #### 看train data資料筆數、Y分佈

# %%
#train data資料筆數
train_new.shape
# Out:
# (1108511, 83)

# %%
#train data Y分佈
train_new['Y'].value_counts()
# Out:
# 0    571094
# 2    280471
# 1    256946
# Name: Y, dtype: int64

# %%
train_new.columns
# Out:
# Index(['X_0', 'X_1', 'X_2', 'X_3', 'X_4', 'X_5', 'X_6', 'X_7', 'X_8', 'X_9',
#        'X_10', 'X_11', 'X_12', 'X_13', 'X_14', 'X_15', 'X_16', 'X_17', 'X_18',
#        'X_19', 'X_20', 'X_21', 'X_22', 'X_23', 'X_24', 'X_25', 'X_26', 'X_27',
#        'X_28', 'X_29', 'X_30', 'X_31', 'X_32', 'X_33', 'X_34', 'X_35', 'X_36',
#        'X_37', 'X_38', 'X_39', 'X_40', 'X_41', 'X_42', 'X_43', 'X_44', 'X_45',
#        'X_46', 'X_47', 'X_48', 'X_49', 'X_50', 'X_51', 'X_52', 'X_53', 'X_54',
#        'X_55', 'X_56', 'X_57', 'X_58', 'X_59', 'X_60', 'X_61', 'X_62', 'X_63',
#        'X_64', 'X_65', 'X_66', 'X_67', 'X_68', 'X_69', 'Y', 'idx',
#        'Diff_cdf_idx', 'X_ec_0', 'X_ec_1', 'X_ec_2', 'X_ec_3', 'X_ec_4',
#        'X_ec_5', 'X_ec_6', 'X_ec_7', 'K_Group', 'K_Dis'],
#       dtype='object')

# %%
train_new[['X_24', 'X_54', 'X_49', 'X_68','X_53', 'X_69', 'X_4', 'X_67']].head(3)
# Out:
#        X_24      X_54      X_49      X_68      X_53      X_69       X_4   X_67
# 0  0.746444  0.190231  0.349136  0.393182  0.609194  0.055556  0.117582  0.352
# 1  0.974448  0.190231  0.349136  0.393182  0.609194  0.055556  0.117582  0.352
# 2 -0.904976  0.190231 -1.020850  0.393182  0.609194  0.055556  0.117582  0.352

# %% [markdown]
# #### 看eval data資料筆數、Y分佈

# %%
eval_new.head(3)
# Out:
#         X_0       X_1       X_2       X_3  ...    X_ec_6    X_ec_7  K_Group  K_Dis
# 0 -0.163385  1.728609  0.142649 -0.176952  ... -0.739701 -0.682902      NaN    NaN
# 1 -0.055390  1.519337  0.142649 -0.176952  ... -0.848680 -0.769913      NaN    NaN
# 2 -0.163385  1.519337  0.142649 -0.176952  ... -0.816643 -0.744334      NaN    NaN
#
# [3 rows x 83 columns]

# %%
eval_new.shape
# Out:
# (1161890, 83)

# %%
#eval data Y分佈
eval_new['Y'].value_counts()
# Out:
# 0    621981
# 2    290870
# 1    249039
# Name: Y, dtype: int64

# %%
Sep_col = ['X_0',"X_24",'X_18']

# %%
train_new[train_new["Y"]!=0][Sep_col].mean(axis=1).quantile(0.4)
# Out:
# -0.4843981518409465

# %%
train_new[train_new["Y"]==0][Sep_col].quantile(0.4)
# Out:
# X_0    -0.444230
# X_24   -0.607608
# X_18   -0.119780
# Name: 0.4, dtype: float64

# %%
train_new['Sep_mean'] = train_new[Sep_col].mean(axis=1)
eval_new['Sep_mean'] = eval_new[Sep_col].mean(axis=1)

# %%
import copy
from collections import deque
from pandas.core.frame import DataFrame
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# %%
def plot_feature_distribution(df0,df1, df2, label0,label1, label2, features,plot_rows,plot_cols):
    i = 0
    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(1,1,figsize=(17,10))

    for feature in features:
        i += 1
        plt.subplot(plot_rows,plot_cols,i)
        sns.distplot(df0[feature], hist=False,label=label0)
        sns.distplot(df1[feature], hist=False,label=label1)
        sns.distplot(df2[feature], hist=False,label=label2)
        plt.xlabel(feature, fontsize=20)
        locs, labels = plt.xticks()
        plt.tick_params(axis='x', which='major', labelsize=6, pad=-6)
        plt.tick_params(axis='y', which='major', labelsize=6)
    plt.show();

# %%
df_0 = train_new[train_new['Y']==0]
df_1 = train_new[train_new['Y']==1]
df_2 = train_new[train_new['Y']==2]
plot_feature_distribution(df_0, df_1,df_2, '0', '1','2', ['Sep_mean'],1,1)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
DarkArt_sccol = 'Sep_mean'
DarkArt_FEcol = 'Sep_mean_kde'

# %%
train_new[DarkArt_FEcol] = train_new[DarkArt_sccol]
eval_new[DarkArt_FEcol] = eval_new[DarkArt_sccol]

# %%
#index長度不同，要標準化
train_new[DarkArt_FEcol] = train_new[DarkArt_FEcol]/max(train_new[DarkArt_FEcol])*100
eval_new[DarkArt_FEcol] = eval_new[DarkArt_FEcol]/max(eval_new[DarkArt_FEcol])*100

# %%
train_new.head(3)
# Out:
#         X_0       X_1       X_2  ...  K_Dis  Sep_mean  Sep_mean_kde
# 0  0.853843 -0.709693  0.142649  ...    NaN  1.006656     27.943602
# 1  1.128771 -0.029401  0.142649  ...    NaN  1.104206     30.651488
# 2  0.508191 -0.029401  0.142649  ...    NaN -0.837543    -23.249236
#
# [3 rows x 85 columns]

# %%
def CDF_func(dataframe,feature,start,end,step,FileName):
    #initial
    N = len(dataframe[feature])
    seq = dataframe[feature].sort_values().reset_index(drop=True)
    cdf_range = range(start,end,step)

    tmp_cdframe = pd.DataFrame(
            [sum(seq<value)/N for value in cdf_range],columns=['cdf'])
    tmp_cdframe.index = cdf_range
    
    globals()['cdf_frame_'+str(FileName)] = tmp_cdframe
    print("Done!File Name: cdf_frame_"+ str(FileName))

# %%
from tqdm import tqdm
for N in tqdm(range(3)):
  CDF_func(train_new[train_new['Y']==N],DarkArt_FEcol,int(min(train_new[DarkArt_FEcol])-10),int(max(train_new[DarkArt_FEcol])+10),10,'feat_'+str(N))
# Out:
#  33%|███▎      | 1/3 [00:02<00:05,  2.73s/it]
# Done!File Name: cdf_frame_feat_0
#  67%|██████▋   | 2/3 [00:03<00:02,  2.18s/it]
# Done!File Name: cdf_frame_feat_1
# 100%|██████████| 3/3 [00:04<00:00,  1.53s/it]
# Done!File Name: cdf_frame_feat_2

# %%
train_new['cdf_idx_0'] = cdf_frame_feat_0.loc[round((train_new[DarkArt_FEcol]//10)*10)].reset_index(drop=True)
train_new['cdf_idx_1'] = cdf_frame_feat_1.loc[round((train_new[DarkArt_FEcol]//10)*10)].reset_index(drop=True)
train_new['cdf_idx_2'] = cdf_frame_feat_2.loc[round((train_new[DarkArt_FEcol]//10)*10)].reset_index(drop=True)

# %%
train_new['Diff_scale'] = train_new[['cdf_idx_1','cdf_idx_2']].min(axis=1)-train_new['cdf_idx_0']
train_new['Diff_var'] = train_new[['cdf_idx_0','cdf_idx_1','cdf_idx_2']].var(axis=1)

# %%
train_new.head(10)
# Out:
#         X_0       X_1       X_2  ...  cdf_idx_2  Diff_scale  Diff_var
# 0  0.853843 -0.709693  0.142649  ...   0.998620   -0.281451  0.065552
# 1  1.128771 -0.029401  0.142649  ...   0.999750   -0.122263  0.010170
# 2  0.508191 -0.029401  0.142649  ...   0.074264   -0.029580  0.001363
# 3 -0.960366  0.067079  0.142649  ...   0.373835   -0.187493  0.034319
# 4 -0.095985  0.063285  0.142649  ...   0.074264   -0.029580  0.001363
# 5 -0.316638 -1.888699  0.142649  ...   0.373835   -0.187493  0.034319
# 6 -0.356190 -0.029401  0.142649  ...   0.373835   -0.187493  0.034319
# 7 -0.895103 -0.029401  0.142649  ...   0.373835   -0.187493  0.034319
# 8 -0.736005 -0.029401 -3.393062  ...   0.074264   -0.029580  0.001363
# 9 -0.946082  1.466674 -2.345616  ...   0.373835   -0.187493  0.034319
#
# [10 rows x 90 columns]

# %%
from tqdm import tqdm
for N in tqdm(range(3)):
  CDF_func(eval_new[eval_new['Y']==N],DarkArt_FEcol,int(min(eval_new[DarkArt_FEcol])-13),int(max(eval_new[DarkArt_FEcol])+17),10,'feat_'+str(N))
# Out:
#  33%|███▎      | 1/3 [00:03<00:06,  3.49s/it]
# Done!File Name: cdf_frame_feat_0
#  67%|██████▋   | 2/3 [00:04<00:02,  2.76s/it]
# Done!File Name: cdf_frame_feat_1
# 100%|██████████| 3/3 [00:05<00:00,  1.92s/it]
# Done!File Name: cdf_frame_feat_2

# %%
eval_new['cdf_idx_0'] = cdf_frame_feat_0.loc[round((eval_new[DarkArt_FEcol]//10)*10)].reset_index(drop=True)
eval_new['cdf_idx_1'] = cdf_frame_feat_1.loc[round((eval_new[DarkArt_FEcol]//10)*10)].reset_index(drop=True)
eval_new['cdf_idx_2'] = cdf_frame_feat_2.loc[round((eval_new[DarkArt_FEcol]//10)*10)].reset_index(drop=True)

# %%
eval_new['Diff_scale'] = eval_new[['cdf_idx_1','cdf_idx_2']].min(axis=1)-eval_new['cdf_idx_0']
eval_new['Diff_var'] = eval_new[['cdf_idx_0','cdf_idx_1','cdf_idx_2']].var(axis=1)

# %% [markdown]
# # Training

# %%
import lightgbm as lgb

# %%
d_train=lgb.Dataset(train_new.drop(['Y','K_Group','K_Dis'], axis=1), label=train_new['Y'])
d_val=lgb.Dataset(eval_new.drop(['Y','K_Group','K_Dis'], axis=1), label=eval_new['Y'])

# %%
del train_new

# %%
params={}
params['learning_rate']=0.3
params['boosting_type']='gbdt' #GradientBoostingDecisionTree
params['objective']='multiclass' #Multi-class target feature ->default:regression
params['metric']='multi_logloss'#params['metric']='binary' #metric for multi-class
params['max_depth']=60
params['num_boost_round']=1000
params['feature_fraction'] = 0.95 # sub_row
params['bagging_fraction'] = 0.95 # sub_row
params['bagging_freq'] = 20
params['num_leaves'] = 100        # num_leaf
params['min_data'] = 300         # min_data_in_leaf        
params['num_class']=3 #no.of unique values in the target class not inclusive of the end value
watchlist = [d_val]

# %%
clfer = lgb.train(params, d_train,d_val,watchlist, early_stopping_rounds=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/lightgbm/engine.py:118: UserWarning: Found `num_boost_round` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's multi_logloss: 0.918487
# Training until validation scores don't improve for 20 rounds.
# [2]	valid_0's multi_logloss: 0.86036
# [3]	valid_0's multi_logloss: 0.820673
# [4]	valid_0's multi_logloss: 0.792116
# [5]	valid_0's multi_logloss: 0.771486
# [6]	valid_0's multi_logloss: 0.756222
# [7]	valid_0's multi_logloss: 0.744186
# [8]	valid_0's multi_logloss: 0.735535
# [9]	valid_0's multi_logloss: 0.729013
# [10]	valid_0's multi_logloss: 0.723895
# [11]	valid_0's multi_logloss: 0.719469
# [12]	valid_0's multi_logloss: 0.716806
# [13]	valid_0's multi_logloss: 0.714992
# [14]	valid_0's multi_logloss: 0.713859
# [15]	valid_0's multi_logloss: 0.712979
# [16]	valid_0's multi_logloss: 0.712595
# [17]	valid_0's multi_logloss: 0.712582
# [18]	valid_0's multi_logloss: 0.713044
# [19]	valid_0's multi_logloss: 0.713021
# [20]	valid_0's multi_logloss: 0.712922
# [21]	valid_0's multi_logloss: 0.713132
# [22]	valid_0's multi_logloss: 0.713632
# [23]	valid_0's multi_logloss: 0.712692
# [24]	valid_0's multi_logloss: 0.713321
# [25]	valid_0's multi_logloss: 0.713941
# [26]	valid_0's multi_logloss: 0.71467
# [27]	valid_0's multi_logloss: 0.715414
# [28]	valid_0's multi_logloss: 0.716265
# [29]	valid_0's multi_logloss: 0.717152
# [30]	valid_0's multi_logloss: 0.717975
# [31]	valid_0's multi_logloss: 0.718954
# [32]	valid_0's multi_logloss: 0.718905
# [33]	valid_0's multi_logloss: 0.718645
# [34]	valid_0's multi_logloss: 0.719967
# [35]	valid_0's multi_logloss: 0.719861
# [36]	valid_0's multi_logloss: 0.720942
# [37]	valid_0's multi_logloss: 0.720703
# Early stopping, best iteration is:
# [17]	valid_0's multi_logloss: 0.712582

# %% [markdown]
# ### Evaluate Model Performance without Kmeans Feature

# %%
val_pred_prob = clfer.predict(eval_new.drop(['Y'], axis=1))

# %%
import numpy as np
val_pred = [np.argmax(x) for x in val_pred_prob]

# %%
val_pred = np.array(val_pred)

# %%
report = metrics.classification_report(eval_new['Y'], val_pred)
Acc = metrics.accuracy_score(eval_new['Y'], val_pred)
print('Report:',report,'\n' 
      'Accuracy:', Acc)
# Out:
# Report:               precision    recall  f1-score   support
#
#            0       0.61      0.71      0.65    621981
#            1       0.59      0.48      0.53    249039
#            2       0.57      0.46      0.51    290870
#
#     accuracy                           0.60   1161890
#    macro avg       0.59      0.55      0.57   1161890
# weighted avg       0.59      0.60      0.59   1161890
#
# Accuracy: 0.5969041819793612

# %%
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"]=(15,30)
plt.rcParams.update({"font.size":22})
lgb.plot_importance(clfer)
